# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib as mpl
import folium

# %%
# Read in data 
zillow_rent = pd.read_csv("./datasets/zillow_rent_by_zipcode.csv")

# %%
# Print Column names
print(list(zillow_rent))
# Print head and tail. 
zillow_rent
# Out:
# ['Date', 'RegionName', 'State', 'Metro', 'County', 'City', 'SizeRank', 'Zri', 'MoM', 'QoQ', 'YoY', 'ZriRecordCnt']
#              Date  RegionName State                           Metro  \
# 0      2017-09-30       10025    NY                        New York
# 1      2017-09-30       60657    IL                         Chicago
# 2      2017-09-30       10023    NY                        New York
# 3      2017-09-30       60614    IL                         Chicago
# 4      2017-09-30       79936    TX                         El Paso
# 5      2017-09-30       10002    NY                        New York
# 6      2017-09-30       60640    IL                         Chicago
# 7      2017-09-30       10467    NY                        New York
# 8      2017-09-30       77084    TX                         Houston
# 9      2017-09-30       94109    CA                   San Francisco
# 10     2017-09-30       75070    TX               Dallas-Fort Worth
# ...

# %%
# Filter to Seattle 
seattle_rent = zillow_rent.loc[(zillow_rent["State"] == "WA") & (zillow_rent["Metro"] == "Seattle")]

seattle_rent
# Out:
#              Date  RegionName State    Metro     County  \
# 110    2017-09-30       98052    WA  Seattle       King
# 196    2017-09-30       98103    WA  Seattle       King
# 206    2017-09-30       98012    WA  Seattle  Snohomish
# 380    2017-09-30       98133    WA  Seattle       King
# 424    2017-09-30       98115    WA  Seattle       King
# 536    2017-09-30       98208    WA  Seattle  Snohomish
# 543    2017-09-30       98034    WA  Seattle       King
# 726    2017-09-30       98122    WA  Seattle       King
# 851    2017-09-30       98125    WA  Seattle       King
# 1016   2017-09-30       98270    WA  Seattle  Snohomish
# 1035   2017-09-30       98003    WA  Seattle       King
# 1113   2017-09-30       98023    WA  Seattle       King
# 1125   2017-09-30       98391    WA  Seattle     Pierce
# 1142   2017-09-30       98118    WA  Seattle       King
# 1190   2017-09-30       98387    WA  Seattle     Pierce
# 1205   2017-09-30       98204    WA  Seattle  Snohomish
# ...

# %%
# Check a few values to see if our understanding of the data is reasonable. 
seattle_rent.loc[seattle_rent["RegionName"] == 98105]
# Out:
#             Date  RegionName State    Metro County     City  SizeRank   Zri  \
# 1272  2017-09-30       98105    WA  Seattle   King  Seattle      1272  3045
#
#            MoM       QoQ       YoY  ZriRecordCnt
# 1272 -0.001967  0.013311  0.063941          8981

# %%
# Making chloropleth
zipcode = pd.read_csv("./datasets/zip_to_coordinates.csv")
zipcode
# latitude = 47.67089
# longitude = -122.31440
# seattle_map = folium.Map(location=[latitude, longitude],
#                    tiles='Mapbox Bright', zoom_start=11)
# seattle_map
# Out:
#          ZIP        LAT         LNG
# 0        601  18.180555  -66.749961
# 1        602  18.361945  -67.175597
# 2        603  18.455183  -67.119887
# 3        606  18.158345  -66.932911
# 4        610  18.295366  -67.125135
# 5        612  18.402253  -66.711397
# 6        616  18.420412  -66.671979
# 7        617  18.445147  -66.559696
# 8        622  17.991245  -67.153993
# 9        623  18.083361  -67.153897
# 10       624  18.064919  -66.716683
# 11       627  18.412600  -66.863926
# 12       631  18.190607  -66.832041
# 13       637  18.076713  -66.947389
# 14       638  18.295913  -66.515588
# 15       641  18.263085  -66.712985
# 16       646  18.433150  -66.285875
# 17       647  17.963613  -66.947127
# 18       650  18.349416  -66.578079
# 19       652  18.448452  -66.594127
# 20       653  17.985033  -66.886536
# 21       656  18.053539  -66.792931
# 22       659  18.407226  -66.808999
# 23       660  18.134695  -67.116199
# 24       662  18.468320  -67.015781
# ...

# %%
# Mean rent in Seattle
sum(seattle_rent["Zri"]) / len(seattle_rent)

# TODO: Calculate other summary statistics
# Out:
# 2213.2876712328766
